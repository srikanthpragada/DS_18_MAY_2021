# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np

# %%
# generate synthetic two-dimensional data
X, y = make_blobs(n_samples = 100, random_state=10)

# %%
X.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %%
y
# Out:
# array([0, 2, 1, 2, 0, 2, 1, 1, 0, 2, 0, 2, 1, 0, 1, 1, 0, 2, 2, 0, 0, 0,
#        0, 2, 1, 0, 2, 1, 0, 2, 0, 1, 0, 2, 2, 0, 0, 2, 1, 2, 1, 0, 2, 1,
#        1, 2, 2, 1, 1, 1, 1, 0, 2, 2, 0, 0, 2, 0, 2, 0, 1, 0, 0, 0, 1, 0,
#        1, 2, 2, 1, 0, 0, 2, 2, 1, 0, 2, 1, 1, 2, 2, 0, 1, 1, 0, 2, 1, 2,
#        2, 1, 2, 1, 1, 2, 1, 1, 0, 0, 1, 0])

# %%
plt.scatter(X[:,0],X[:,1])
plt.xlabel('Feature1', fontsize=14)
plt.ylabel('Feature2', fontsize=14)
# Out:
# Text(0, 0.5, 'Feature2')

# %%
kmeans = KMeans(n_clusters=3, max_iter=10)
kmeans.fit(X)
# Out:
# KMeans(max_iter=10, n_clusters=3)

# %%
labels = kmeans.labels_
labels
# Out:
# array([0, 1, 2, 1, 0, 1, 2, 2, 0, 1, 0, 1, 2, 0, 2, 2, 0, 1, 1, 0, 0, 0,
#        0, 1, 2, 0, 1, 2, 0, 1, 0, 2, 0, 1, 1, 0, 0, 1, 2, 1, 2, 0, 1, 2,
#        2, 1, 1, 2, 2, 2, 2, 0, 1, 1, 0, 0, 1, 0, 1, 0, 2, 0, 0, 0, 2, 0,
#        2, 1, 1, 2, 0, 0, 1, 1, 2, 0, 1, 2, 2, 1, 1, 0, 2, 2, 0, 1, 2, 1,
#        1, 2, 1, 2, 2, 1, 2, 2, 0, 0, 2, 0])

# %%
# Centroids 
centers = kmeans.cluster_centers_
centers
# Out:
# array([[ 0.70353328, -4.52767455],
#        [-9.52981151, -7.69781936],
#        [-1.72134158,  6.61045437]])

# %%
plt.scatter(X[:,0],X[:,1], c=labels.astype(np.float))
plt.xlabel('Feature1', fontsize=14)
plt.ylabel('Feature2', fontsize=14)
# draw centers 
plt.scatter(centers[:,0], centers[:,1], c="red", marker="s")
plt.show()

# %%
print(kmeans.transform(X[:10]))
print(labels[:10])
# Out:
# [[ 1.18306525 10.76089655 10.22266502]
#  [10.99402169  0.96596434 17.13228375]
#  [10.5713654  15.40984381  0.92552772]
#  [10.78664931  2.17811678 14.75231924]
#  [ 0.22104303 10.60503876 11.21805858]
#  [ 9.18775712  1.54046387 15.09389416]
#  [11.93791357 17.4089018   1.22062282]
#  [11.0315513  15.88823299  0.42161248]
#  [ 0.60601893 10.60631998 10.81991373]
#  [ 9.48765167  2.34564328 13.98698168]]
# [0 1 2 1 0 1 2 2 0 1]

# %%
kmeans.inertia_
# Out:
# 195.4001076475894

# %%
kmeans.n_iter_
# Out:
# 2

# %%
kmeans.score(X)
# Out:
# -195.4001076475894

# %%
cost = []
for k in range(2,6):
   kmeans = KMeans(n_clusters=k)
   kmeans.fit(X)
   cost.append(kmeans.inertia_)

# %%
plt.plot(range(2,6), cost)
plt.xlabel("K")
plt.ylabel("Inertia (Cost)")
# Out:
# Text(0, 0.5, 'Inertia (Cost)')
