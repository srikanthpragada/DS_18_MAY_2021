# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np

# %%
# generate synthetic two-dimensional data
X, y = make_blobs(n_samples = 100, random_state=10)

# %%
X.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %%
y
# Out:
# array([0, 2, 1, 2, 0, 2, 1, 1, 0, 2, 0, 2, 1, 0, 1, 1, 0, 2, 2, 0, 0, 0,
#        0, 2, 1, 0, 2, 1, 0, 2, 0, 1, 0, 2, 2, 0, 0, 2, 1, 2, 1, 0, 2, 1,
#        1, 2, 2, 1, 1, 1, 1, 0, 2, 2, 0, 0, 2, 0, 2, 0, 1, 0, 0, 0, 1, 0,
#        1, 2, 2, 1, 0, 0, 2, 2, 1, 0, 2, 1, 1, 2, 2, 0, 1, 1, 0, 2, 1, 2,
#        2, 1, 2, 1, 1, 2, 1, 1, 0, 0, 1, 0])

# %%
plt.scatter(X[:,0],X[:,1])
plt.xlabel('Feature1', fontsize=14)
plt.ylabel('Feature2', fontsize=14)
# Out:
# Text(0, 0.5, 'Feature2')

# %%
kmeans = KMeans(n_clusters=3, max_iter=10)
kmeans.fit(X)
# Out:
# KMeans(max_iter=10, n_clusters=3)

# %%
labels = kmeans.labels_
labels
# Out:
# array([1, 1, 0, 2, 0, 0, 2, 1, 0, 2, 2, 0, 0, 1, 1, 0, 2, 0, 2, 0, 2, 1,
#        0, 1, 2, 0, 0, 0, 0, 2, 1, 0, 0, 2, 1, 1, 1, 0, 0, 0, 1, 2, 1, 1,
#        0, 2, 2, 2, 1, 2, 0, 1, 2, 2, 1, 2, 0, 1, 2, 2, 0, 0, 1, 1, 1, 2,
#        2, 1, 1, 1, 0, 2, 0, 0, 1, 0, 0, 1, 2, 2, 2, 0, 2, 0, 1, 0, 1, 2,
#        1, 1, 2, 2, 2, 1, 1, 1, 0, 2, 2, 2])

# %%
# Centroids 
centers = kmeans.cluster_centers_
centers
# Out:
# array([[ 2.84050716,  4.85840422],
#        [ 0.08921213, -5.46441742],
#        [ 5.6183469 , -9.54288499]])

# %%
plt.scatter(X[:,0],X[:,1], c= labels.astype(np.float))
plt.xlabel('Feature1', fontsize=14)
plt.ylabel('Feature2', fontsize=14)
# draw centers 
plt.scatter(centers[:,0], centers[:,1], c="red", marker="s")
plt.show()
# Out:
# <ipython-input-30-ce122594abe9>:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   plt.scatter(X[:,0],X[:,1], c= labels.astype(np.float))

# %%
print(kmeans.transform(X[:10]))
print(labels[:10])
# Out:
# [[12.66012274  2.7119914   8.43671672]
#  [10.03168954  0.70847346  6.89609041]
#  [ 1.08714957  9.60385746 13.76077949]
#  [15.07961458  7.26589392  0.43307887]
#  [ 0.91556546 10.92857897 15.25996233]
#  [ 0.8597614  10.19866225 13.91296253]
#  [15.4989238   7.67696883  0.87480072]
#  [ 9.67363774  1.31820101  8.03107398]
#  [ 1.00752823 11.30473097 14.8774384 ]
#  [12.39107446  5.86590741  2.34406396]]
# [1 1 0 2 0 0 2 1 0 2]

# %%
kmeans.inertia_
# Out:
# 186.3658862010145

# %%
kmeans.n_iter_
# Out:
# 5

# %%
kmeans.score(X)
# Out:
# -186.3658862010145

# %%
cost = []
for k in range(2,6):
   kmeans = KMeans(n_clusters=k)
   kmeans.fit(X)
   cost.append(kmeans.inertia_)

# %%
plt.plot(range(2,6), cost)
plt.xlabel("K")
plt.ylabel("Inertia (Cost)")
# Out:
# Text(0, 0.5, 'Inertia (Cost)')
